# %%
import requests
import os
from dotenv import load_dotenv

# %% [markdown]
# ### Authorization

# %%
load_dotenv()
api_key = os.getenv("CLIENT_ID")
api_secret = os.getenv("API_SECRET")

# %%
auth_url = 'https://accounts.spotify.com/api/token'

data = {
    'grant_type': 'client_credentials',
    'client_id': api_key,
    'client_secret': api_secret,
}

auth_response = requests.post(auth_url, data=data)

# %%
access_token = auth_response.json().get('access_token')

base_url = 'https://api.spotify.com/v1/'
headers = {
    'Authorization': 'Bearer {}'.format(access_token)
}

# %%
r = requests.get("https://api.spotify.com/v1/playlists/387OhCc6mEbm96wzfFfhpp", headers=headers)

# %%
playlists = r.json()

# %%
playlists["tracks"]["items"][40]["track"]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#     'href': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH',
#     'id': '7Ln80lUS6He07XvHI8qqHH',
#     'name': 'Arctic Monkeys',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Ln80lUS6He07XvHI8qqHH'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
# ...

# %%
track_id = "5kxVyCgEUND7E2QKG7JmoF"

# %%
r = requests.get(f"https://api.spotify.com/v1/audio-features/{track_id}", headers=headers)

# %%
r.json()
# Out:
# {'danceability': 0.637,
#  'energy': 0.963,
#  'key': 9,
#  'loudness': -5.116,
#  'mode': 1,
#  'speechiness': 0.0882,
#  'acousticness': 0.000286,
#  'instrumentalness': 0.000889,
#  'liveness': 0.0449,
#  'valence': 0.823,
#  'tempo': 150.1,
#  'type': 'audio_features',
#  'id': '5kxVyCgEUND7E2QKG7JmoF',
#  'uri': 'spotify:track:5kxVyCgEUND7E2QKG7JmoF',
#  'track_href': 'https://api.spotify.com/v1/tracks/5kxVyCgEUND7E2QKG7JmoF',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5kxVyCgEUND7E2QKG7JmoF',
#  'duration_ms': 165000,
#  'time_signature': 4}
